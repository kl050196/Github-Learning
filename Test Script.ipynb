# %%
# !git clone https://github.com/kl050196/Github-Learning
# Out:
# fatal: destination path 'Github-Learning' already exists and is not an empty directory.

# %%
1+1
# Out:
# 2

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Test Script.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
pwd
# Out:
# 'e:\\Git\\Repos\\Github-Learning\\Github-Learning'

# %% [markdown]
# sdfsdfsdf

# %%
# Add Script to Repo
